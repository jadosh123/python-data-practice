# %% [markdown]
# # Rolling the Die

# %%
from die import Die

die = Die()
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

frequencies = []
for num in range(1, die.num_sides+1):
    frequencies.append(results.count(num))

print(frequencies)
print(results)
# Out:
# [170, 151, 151, 168, 190, 170]
# ...

# %% [markdown]
# Making a histogram to analyze the results

# %%
from plotly.graph_objs import Bar, Layout
from plotly import offline

x_values = [x for x in range(1, die.num_sides+1)]
data = [Bar(x=x_values, y=frequencies)]

x_axis_config = {'title': 'Result'}
y_axis_config = {'title': 'Frequency of Result'}
my_layout = Layout(title='Results of rolling one D6 1000 times',
                   xaxis=x_axis_config, yaxis=y_axis_config)

# This opens a page in default browser that displays a interactable histogram
offline.plot({'data': data, 'layout': my_layout}, filename='d6.html')
